# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('net_index/region_daily_speeds_name_matched.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b8bde798657d> in <module>
# ----> 1 df = pd.read_csv('net_index/region_daily_speeds_name_matched.csv')
#
# c:\users\tomzh\miniconda3\envs\ml\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df.head().T
# Out:
#                           0            1            2            3  \
# country         Afghanistan  Afghanistan  Afghanistan  Afghanistan
# region                Kabul        Kabul        Kabul        Kabul
# date             2010-07-15   2010-07-16   2010-07-17   2010-07-18
# download_kbps         226.6      270.211      313.048      360.694
# upload_kbps           105.9      106.895      114.143      109.863
# total_tests              10           19           21           31
# distance_miles       244.01      238.295      237.076      234.949
#
#                           4
# country         Afghanistan
# region                Kabul
# date             2010-07-19
# download_kbps       447.529
# upload_kbps         105.736
# total_tests              35
# distance_miles      236.993

# %%
df.groupby(['country', 'region']).agg({'date': 'min'})
# Out:
#                                              date
# country              region
# Afghanistan          Kabul             2010-07-15
# Albania              Durrës            2014-07-18
#                      Shkodër           2011-10-22
#                      Tiranë            2008-01-01
# Algeria              Alger             2008-01-01
# ...                                           ...
# Vietnam              Đồng Tháp         2012-03-02
# Virgin Islands, U.S. \N                2008-09-03
# Zambia               Lusaka            2010-06-08
# Zimbabwe             Mashonaland East  2011-01-11
# Åland                \N                2010-09-05
#
# [1275 rows x 1 columns]
